# %%
import pyfpgrowth
import pandas
from pandas import read_csv

# %%
data = read_csv("D:\github\SenseMining\SenseMining\SenseMining\SenseMining\Resourses\mushroom.dat", nrows=100, header=None, sep=' ')
data = data.drop(data.columns[[23]], axis=1) #удаляем последнюю колонку с пробелами
transactions = data.values.tolist()
print(transactions)
# Out:
# [[1, 3, 9, 13, 23, 25, 34, 36, 38, 40, 52, 54, 59, 63, 67, 76, 85, 86, 90, 93, 98, 107, 113], [2, 3, 9, 14, 23, 26, 34, 36, 39, 40, 52, 55, 59, 63, 67, 76, 85, 86, 90, 93, 99, 108, 114], [2, 4, 9, 15, 23, 27, 34, 36, 39, 41, 52, 55, 59, 63, 67, 76, 85, 86, 90, 93, 99, 108, 115], [1, 3, 10, 15, 23, 25, 34, 36, 38, 41, 52, 54, 59, 63, 67, 76, 85, 86, 90, 93, 98, 107, 113], [2, 3, 9, 16, 24, 28, 34, 37, 39, 40, 53, 54, 59, 63, 67, 76, 85, 86, 90, 94, 99, 109, 114], [2, 3, 10, 14, 23, 26, 34, 36, 39, 41, 52, 55, 59, 63, 67, 76, 85, 86, 90, 93, 98, 108, 114], [2, 4, 9, 15, 23, 26, 34, 36, 39, 42, 52, 55, 59, 63, 67, 76, 85, 86, 90, 93, 98, 108, 115], [2, 4, 10, 15, 23, 27, 34, 36, 39, 41, 52, 55, 59, 63, 67, 76, 85, 86, 90, 93, 99, 107, 115], [1, 3, 10, 15, 23, 25, 34, 36, 38, 43, 52, 54, 59, 63, 67, 76, 85, 86, 90, 93, 98, 110, 114], [2, 4, 9, 14, 23, 26, 34, 36, 39, 42, 52, 55, 59, 63, 67, 76, 85, 86, 90, 93, 98, 107, 115], [2, 3, 10, 14, 23, 27, 34, 36, 39, 42, 52, 55, 59, 63, 67, 76, 
# ...

# %%
#import base64
#base64func = lambda x: base64.b64encode(x.encode())
#transactions = transactions.applymap(base64func)

#print(transactions)

# %%
#patterns = pyfpgrowth.find_frequent_patterns(transactions, 1)

# %%
#print ('patterns:')
#print (len(patterns))
#print (patterns)

# %%
#rules = pyfpgrowth.generate_association_rules(patterns, 0.5)

# %%
#print ('rules:')
#print (len(rules))
#print (rules)

# %%
from orangecontrib.associate.fpgrowth import *

# %%
itemsets = frequent_itemsets(transactions, 1)

# %%
list(itemsets)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_code(self, code_obj, result)
#    2909                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2910                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2911             finally:
#
# <ipython-input-254-02b0865c189e> in <module>()
# ----> 1 list(itemsets)
#
# ~\Anaconda3\lib\site-packages\orangecontrib\associate\fpgrowth.py in frequent_itemsets(X, min_support)
#     442     if tree:
# --> 443         yield from _fp_growth(tree, frozenset(), min_support)
#     444
#
# ~\Anaconda3\lib\site-packages\orangecontrib\associate\fpgrowth.py in _fp_growth(tree, alpha, min_support)
#     347         yield itemsetQ, supportQ
# --> 348         for itemsetP, supportP in _freq_patterns_single(P, alpha, min_support):
# ...

# %%
import pyfpgrowth
import pandas
from pandas import read_csv

# %%
transactions = read_csv("D:\github\SenseMining\SenseMining\SenseMining\SenseMining\Resourses\mushroom.dat", nrows=1000)

# %%
patterns = pyfpgrowth.find_frequent_patterns(transactions, 1)

# %%
print ('patterns:')
print (len(patterns))
# Out:
# patterns:
# 2047
